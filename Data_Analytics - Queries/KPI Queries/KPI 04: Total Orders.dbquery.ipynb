-- %%
-- KPI 04: Total Orders
-- Purpose:
-- Calculates the total number of unique non-cancelled orders.

SELECT
    COUNT(DISTINCT order_id) AS total_orders
FROM `end-to-end_pipeline`.gold.fact_sales
WHERE order_status <> 'Cancelled';
