# %% [markdown]
# Use this cleaner master prompt — it’s more precise and should stop Genie from adding random extra logic:
#
# > **I’m building an end-to-end Databricks Medallion Architecture project following Bronze → Silver → Gold. The Bronze and Silver layers are complete.**
# >
# > Create a professional **Databricks SQL notebook** for the specified Gold table.
# >
# > **Source:** `[silver source table]`
# > **Target:** `[gold target table]`
# >
# > Follow this notebook structure:
# >
# > **Notebook Header**
# >
# > * Gold layer table name
# > * Source and target
# > * Short business purpose
# > * Approach: Profile → Inspect → Transform → Validate
# >
# > **Cell 1 — Profile**
# > Review the Silver source specifically for what is needed to create the Gold model. Do not repeat Silver cleaning.
# >
# > **Cell 2 — Inspect**
# > Inspect the important business attributes, keys, and relationships required for the Gold table.
# >
# > **Cell 3 — Transform**
# > Create the Gold table using `CREATE OR REPLACE TABLE`.
# > Keep the SQL simple, readable, and maintainable.
# > Apply only Gold-layer business modeling and business logic.
# >
# > **Cell 4 — Validate**
# > Validate row count, key uniqueness, required fields, and relevant business rules. Return an overall `PASS` or `FAIL`.
# >
# > **Important rules:**
# >
# > * Do not repeat Bronze or Silver cleaning.
# > * Do not add unnecessary transformations.
# > * Use business-friendly Gold naming.
# > * Keep primary/business keys needed for relationships.
# > * Use explicit columns in the final Gold table.
# > * Add a clear Markdown heading and brief description before each cell.
# > * Explain why each Gold transformation is needed.
# > * Do not over-engineer the SQL.
# >
# > Use these mappings:
# >
# > `silver.customers` → `gold.dim_customer`
# > `silver.products` → `gold.dim_product`
# > `silver.stores` → `gold.dim_store`
# > `silver.suppliers` → `gold.dim_supplier`
# > `silver.calendar` → `gold.dim_date`
# > `silver.sales_transactions` → `gold.fact_sales`
# >
# > For dimension tables, focus on business-ready descriptive attributes and keys.
# >
# > For `gold.fact_sales`, create the transactional fact table and include appropriate business measures such as quantity, selling price, cost, discount, revenue, cost amount, and profit where justified by the existing dataset.
# >
# > **Work on one Gold table at a time. Do not generate all six notebooks at once.**
#
# That last line is important. Otherwise Genie may wake up feeling ambitious and build the entire data warehouse before breakfast. 👀
